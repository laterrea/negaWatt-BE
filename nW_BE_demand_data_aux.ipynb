# %% [markdown]
# <div align="justify"><h1><b><font size="6">
#   Auxilliary Data for Modelling the Demand Parameters in the negaWatt-BE Scenario (update)</h1></font></div>
# <div align="justify"><h2><b><font size="5">
#   AUXILLIARY DATA
# </h2></font></b></div>
#
# ---
# <div align="justify"><h3><font size="3">
#   <b> Developer:</b> LATERRE Antoine
# </h3></font></div>
#
# ---
#
# To ensure transparency and consistency within the negaWatt-BE project, this notebook documents all key input assumptions related to the auxilliary data.

# %%
# Automatically reload the file if it is modified:
# %load_ext autoreload
# %autoreload 2

# Import packages:
import numpy as np
import matplotlib.pyplot as plt

# Load the macro parameters:
# %run ./nW_BE_demand_model_macro.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
population_dic_STATBEL = np.array([10239085, 10263414, 10309725, 10355844, 10396421, 10445852, 10511382, 10584534, 10665140, 10753080, 10839905, 10951266, 11035948, 11099554, 11150516, 11209044, 11267910, 11322088, 11376070, 11431406, 11492641, 11521238, 11584008, 11697557])
households_dic_STATBEL = np.array([4258968, 4292079, 4326515, 4369303, 4415999, 4452637, 4494873, 4537819, 4582785, 4621490, 4665956, 4708210, 4746896, 4772191, 4790102, 4822301, 4848184, 4877805, 4911973, 4948398, 4988930, 5024851, 5068347, 5124561])

# %% [markdown]
# <font size="5"><b>Transport Sector</b></font><a class="anchor" id="contents"></a> <br>
#
# <font size="3"><b>Passenger mobility</b></font><a class="anchor" id="contents"></a> <br>

# %%
# JRC-IDEES-2023
# -> Population: Eurostat
years_JRC = np.array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

passenger_mob_tot_JRC  = np.array([146.650, 147.834, 144.258, 144.843, 149.463, 148.970, 150.736, 155.472, 160.873, 160.727, 164.081, 167.393, 168.254, 161.977, 166.399, 165.571, 161.376, 165.667, 170.382, 172.657, 121.602, 132.336, 156.637, 166.921])
passenger_mob_road_JRC = np.array([117.433, 118.891, 121.561, 120.815, 122.049, 122.135, 122.614, 125.255, 127.508, 127.628, 128.602, 129.473, 129.814, 122.743, 125.293, 123.142, 121.527, 122.001, 122.478, 122.878, 101.887, 107.680, 114.383, 120.598])
passenger_mob_rail_JRC = np.array([8.604, 8.914, 9.150, 9.165, 10.135, 9.440, 9.914, 10.373, 11.139, 11.237, 11.568, 11.802, 12.076, 12.126, 12.202, 11.772, 11.292, 11.760, 13.222, 13.472, 8.799, 8.820, 12.616, 13.623])
passenger_mob_avia_JRC = np.array([20.613, 20.029, 13.547, 14.862, 17.279, 17.395, 18.208, 19.845, 22.226, 21.861, 23.910, 26.119, 26.365, 27.109, 28.904, 30.658, 28.557, 31.906, 34.683, 36.306, 10.916, 15.836, 29.639, 32.699])

passenger_mob_tot_spe  = passenger_mob_tot_JRC/population_dic_STATBEL*1e+9
passenger_mob_road_spe = passenger_mob_road_JRC/population_dic_STATBEL*1e+9
passenger_mob_rail_spe = passenger_mob_rail_JRC/population_dic_STATBEL*1e+9
passenger_mob_avia_spe = passenger_mob_avia_JRC/population_dic_STATBEL*1e+9

fig = plt.figure()
plt.plot(years_JRC,passenger_mob_tot_spe,label='total')
plt.plot(years_JRC,passenger_mob_road_spe,label='road')
plt.plot(years_JRC,passenger_mob_rail_spe,label='rail')
plt.plot(years_JRC,passenger_mob_avia_spe,label='aviation')
plt.ylabel('km/year/person')
plt.xlabel('year')
plt.legend()
#plt.ylim([13000,15500])

growth_tot =  (passenger_mob_tot_spe[19]-passenger_mob_tot_spe[0])#/(years_JRC[19]-years_JRC[0])
growth_road = (passenger_mob_road_spe[19]-passenger_mob_road_spe[0])#/(years_JRC[19]-years_JRC[0])
growth_rail = (passenger_mob_rail_spe[19]-passenger_mob_rail_spe[0])#/(years_JRC[19]-years_JRC[0])
growth_avia = (passenger_mob_avia_spe[19]-passenger_mob_avia_spe[0])#/(years_JRC[19]-years_JRC[0])

#plt.title(f'total, 2000 to 2019: +{round(growth_tot,0)} [pkm/year/person]')
#plt.title(f'road, 2000 to 2019: +{round(growth_road,0)} [pkm/year/person ]')
#plt.title(f'rail, 2000 to 2019: +{round(growth_rail,0)} [pkm/year/person]')
#plt.title(f'aviation, 2000 to 2019: +{round(growth_avia,0)} [pkm/year/person ]')

growth_tot =  (passenger_mob_tot_spe[19]-passenger_mob_tot_spe[0])/passenger_mob_tot_spe[0]*100
growth_road = (passenger_mob_road_spe[19]-passenger_mob_road_spe[0])/passenger_mob_tot_spe[0]*100
growth_rail = (passenger_mob_rail_spe[19]-passenger_mob_rail_spe[0])/passenger_mob_tot_spe[0]*100
growth_avia = (passenger_mob_avia_spe[19]-passenger_mob_avia_spe[0])/passenger_mob_tot_spe[0]*100

plt.title(f'total, 2000 to 2019: +{round(growth_tot,1)} [%]')
#plt.title(f'road, 2000 to 2019: +{round(growth_road,1)} [%]')
#plt.title(f'rail, 2000 to 2019: +{round(growth_rail,1)} [%]')
#plt.title(f'aviation, 2000 to 2019: +{round(growth_avia,1)} [%]')
# Out:
# Text(0.5, 1.0, 'total, 2000 to 2019: +5.5 [%]')

# %%
car_total    = np.array([102544.4, 103440.6, 104843.4, 102494.9, 103034.0, 102804.3, 102659.6, 104570.4, 107942.9, 108073.8, 109387.8, 109969.5, 110141.1, 105293.1, 108110.6, 107002.0, 106139.8, 106940.0, 107319.9, 107444.7, 91438.8, 96748.1, 100828.3, 105305.7])
car_gasoline = np.array([43864.8, 41719.3, 40209.2, 38418.0, 34316.4, 32824.2, 29479.0, 27128.4, 25011.3, 23851.3, 22325.3, 21727.3, 21665.0, 21471.8, 23069.7, 24072.0, 25907.1, 28558.2, 32875.6, 37609.9, 32338.5, 38312.3, 44223.1, 49964.5])
car_diesel   = np.array([57682.4, 60557.2, 63441.9, 63025.8, 67733.3, 69076.7, 72372.6, 76734.6, 82273.1, 83627.2, 86521.0, 87636.7, 87827.9, 83244.4, 84360.5, 81967.5, 79183.1, 77066.6, 72882.8, 67959.1, 56916.0, 55185.2, 51901.9, 47934.2])
car_LPG      = np.array([997.1, 1164.1, 1192.3, 1051.1, 979.0, 897.3, 802.1, 701.7, 653.2, 590.5, 535.5, 594.6, 624.6, 549.6, 616.2, 829.1, 760.2, 770.8, 757.2, 740.0, 667.9, 664.4, 653.3, 666.0])
car_NG       = np.array([np.nan, np.nan, np.nan, np.nan, 5.2, 6.0, 5.9, 5.8, 5.0, 4.6, 4.8, 5.2, 5.3, 7.9, 20.7, 38.8, 82.0, 126.5, 222.6, 309.6, 340.4, 372.8, 373.3, 372.0])
car_PHEV     = np.array([np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0.2, 3.9, 4.1, 13.6, 48.5, 136.2, 273.3, 426.4, 570.4, 832.9, 1539.0, 2510.1, 3867.4])
car_BEV      = np.array([np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0.2, 0.2, 1.0, 5.5, 14.3, 15.5, 29.9, 46.0, 71.1, 144.5, 155.4, 255.7, 343.0, 674.4, 1166.6, 2501.6])

rel_gasoline = 100*car_gasoline/car_total
rel_diesel   = 100*car_diesel/car_total
rel_LPG      = 100*car_LPG/car_total
rel_NG       = 100*car_NG/car_total
rel_PHEV     = 100*car_PHEV/car_total
rel_BEV      = 100*car_BEV/car_total

fig = plt.figure()
plt.plot(years_JRC,car_gasoline,label='gasoline')
plt.plot(years_JRC,car_diesel,  label='diesel')
plt.plot(years_JRC,car_LPG,     label='LPG')
plt.plot(years_JRC,car_NG,      label='NG')
plt.plot(years_JRC,car_PHEV,    label='PHEV')
plt.plot(years_JRC,car_BEV,     label='BEV')
plt.ylabel('Gpkm/year')
plt.xlabel('year')
plt.legend()

fig = plt.figure()
#plt.plot(years_JRC,rel_gasoline,label='gasoline')
#plt.plot(years_JRC,rel_diesel,  label='diesel')
plt.plot(years_JRC,rel_LPG,     label='LPG')
plt.plot(years_JRC,rel_NG,      label='NG')
plt.plot(years_JRC,rel_PHEV,    label='PHEV')
plt.plot(years_JRC,rel_BEV,     label='BEV')
plt.ylabel('%')
plt.xlabel('year')
plt.legend()

fig = plt.figure()
plt.plot(years_JRC,rel_gasoline,label='gasoline')
plt.plot(years_JRC,rel_diesel,  label='diesel')
plt.plot(years_JRC,rel_diesel+rel_gasoline,  label='gasoline+diesel')
plt.ylabel('%')
plt.xlabel('year')
plt.legend()

y = 23
print(rel_gasoline[y]) 
print(rel_diesel[y]) 
print(rel_LPG[y]) 
print(rel_NG[y]) 
print(rel_PHEV[y]) 
print(rel_BEV[y])
# Out:
# 47.44709925483616
# 45.5190934583788
# 0.6324443975967113
# 0.35325723109005497
# 3.672545740638921
# 2.3755599174593587

# %%
bus_total    = np.array([13298.3, 13785.3, 14959.4, 16483.6, 17143.0, 17515.0, 18078.0, 18729.6, 17610.0, 17630.0, 17380.0, 17670.0, 17910.0, 15766.4, 15404.6, 14380.8, 13586.6, 13362.6, 13522.3, 13681.4, 8871.6, 9275.1, 11866.6, 13463.5])
bus_gasoline = np.array([68.5, 69.6, 69.6, 77.1, 78.2, 79.9, 76.3, 75.2, 64.4, 59.7, 53.6, 53.5, 53.1, 43.4, 39.2, 36.3, 36.6, 34.7, 34.4, 33.9, 26.0, 25.4, 28.1, 31.1])
bus_diesel   = np.array([13228.1, 13714.0, 14888.0, 16404.5, 17062.7, 17412.7, 17978.1, 18630.9, 17525.1, 17549.5, 17306.9, 17597.3, 17838.2, 15700.5, 15341.8, 14324.8, 13529.1, 13306.3, 13446.9, 13581.4, 8785.8, 9093.3, 11574.2, 12965.3])
bus_LPG      = np.array([np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan])
bus_NG       = np.array([np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 6.1, 5.9, 5.3, 7.2, 9.0, 22.2, 13.1, 16.1, 92.2, 147.2, 169.1])
bus_BEV      = np.array([1.6, 1.7, 1.8, 2.0, 2.1, 22.5, 23.7, 23.5, 20.6, 20.8, 19.5, 19.2, 18.7, 16.4, 17.7, 14.4, 13.7, 12.6, 18.9, 53.0, 43.7, 64.2, 117.1, 298.0])

rel_gasoline = 100*bus_gasoline/bus_total
rel_diesel   = 100*bus_diesel/bus_total
rel_LPG      = 100*bus_LPG/bus_total
rel_NG       = 100*bus_NG/bus_total
rel_BEV      = 100*bus_BEV/bus_total

fig = plt.figure()
plt.plot(years_JRC,bus_gasoline,label='gasoline')
plt.plot(years_JRC,bus_diesel,  label='diesel')
plt.plot(years_JRC,bus_LPG,     label='LPG')
plt.plot(years_JRC,bus_NG,      label='NG')
plt.plot(years_JRC,bus_BEV,     label='BEV')
plt.ylabel('Gpkm/year')
plt.xlabel('year')
plt.legend()

fig = plt.figure()
plt.plot(years_JRC,rel_gasoline,label='gasoline')
#plt.plot(years_JRC,rel_diesel,  label='diesel')
plt.plot(years_JRC,rel_LPG,     label='LPG')
plt.plot(years_JRC,rel_NG,      label='NG')
plt.plot(years_JRC,rel_BEV,     label='BEV')
plt.ylabel('%')
plt.xlabel('year')
plt.legend()

y = 19
print(rel_gasoline[y]) 
print(rel_diesel[y]) 
print(rel_LPG[y]) 
print(rel_NG[y]) 
print(rel_BEV[y]) 
print(rel_BEV[y]/rel_BEV[19])
# Out:
# 0.2477816597716608
# 99.26908064964113
# nan
# 0.09575043489701347
# 0.38738725569020716
# 1.0

# %% [markdown]
# <font size="3"><b>Freight transport</b></font><a class="anchor" id="contents"></a> <br>

# %%
# JRC-IDEES-2023
# -> Population: Eurostat

freight_tra_tot_JRC  = np.array([56.805, 58.841, 60.320, 60.258, 64.468, 66.058, 68.831, 71.431, 68.912, 61.328, 66.266, 66.622, 74.632, 75.188, 76.076, 79.256, 84.875, 81.156, 76.076, 80.176, 78.650, 82.344, 76.524, 75.503])
freight_tra_tot_spe  = freight_tra_tot_JRC/population_dic_STATBEL*1e+9

fig = plt.figure()
plt.plot(years_JRC,freight_tra_tot_spe,label='total')

plt.ylabel('tkm/year/person')
plt.xlabel('year')
plt.legend()
#plt.ylim([13000,15500])

#growth_tot =  (passenger_mob_tot_spe[19]-passenger_mob_tot_spe[0])#/(years_JRC[19]-years_JRC[0])

#plt.title(f'total, 2000 to 2019: +{round(growth_tot,0)} [km/year/person / year]')

growth_tot =  (freight_tra_tot_spe[19]-freight_tra_tot_spe[0])/freight_tra_tot_spe[0]*100

plt.title(f'total, 2000 to 2019: +{round(growth_tot,1)} [%]')

freight_tra_tot_spe[23]
# Out:
# 6454.595604877155

# %%
freight_tra_road_JRC        = np.array([40.263, 42.533, 43.646, 43.241, 46.832, 47.692, 48.931, 50.076, 48.110, 45.487, 46.705, 46.637, 46.912, 48.626, 49.020, 51.606, 53.435, 53.195, 52.003, 53.532, 52.967, 55.935, 53.030, 51.781])
freight_tra_road_spe        = freight_tra_road_JRC/population_dic_STATBEL*1e+9

freight_tra_navi_inland_JRC = np.array([7.215, 7.655, 8.073, 8.230, 8.392, 8.566, 8.908, 9.006, 8.746, 7.087, 9.070, 9.251, 10.420, 10.365, 10.451, 10.426, 10.331, 11.098, 7.986, 7.767, 7.388, 8.180, 7.559, 6.951])
freight_tra_navi_inland_spe = freight_tra_navi_inland_JRC/population_dic_STATBEL*1e+9


fig = plt.figure()
plt.plot(years_JRC,freight_tra_road_spe,       label='road')
plt.plot(years_JRC,freight_tra_navi_inland_spe,label='inland navigation')
plt.ylabel('tkm/person')
plt.xlabel('year')
plt.legend()
#plt.ylim([13000,15500])
growth_tot =  (freight_tra_road_spe[19]-freight_tra_road_spe[0])/freight_tra_road_spe[0]*100
plt.title(f'total, 2000 to 2019: {round(growth_tot,1)} [%]')

freight_tra_road_spe[19]
# Out:
# 4682.888526573196

# %% [markdown]
# <font size="5"><b>Tertiary Sector</b></font><a class="anchor" id="contents"></a> <br>
#
# <font size="3"><b>Total floor area</b></font><a class="anchor" id="contents"></a> <br>

# %%
# JRC-IDEES-2023
# -> Population: Eurostat
# -> Surface: extrapolation from  EU Building Observatory (2020)
years_JRC = np.array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

population_dict_EU27_JRC = np.array([428473834, 429240746, 429728905, 431246056, 432878129, 434585887, 436041018, 437514477, 439074280, 440467898, 441160594, 440526112, 441280191, 441739935, 442268078, 442924865, 444003268, 444670605, 445301376, 446149924, 447030024, 445891011, 445998928, 447695350])
population_dict_FR_JRC   = np.array([ 60545022,  60979315,  61424036,  61864088,  62292241,  62772870,  63229635,  63645065,  64007193,  64350226,  64658856,  64978721,  65276983,  65600350,  66165980,  66458153,  66638391,  66809816,  67026224,  67290471,  67473651,  67728568,  68091703,  68277210])
population_dict_DE_JRC   = np.array([ 82163475,  82259540,  82440309,  82536680,  82531671,  82500849,  82437995,  82314906,  82217837,  82002356,  81802257,  80222065,  80327900,  80523746,  80767463,  81197537,  82175684,  82521653,  82792351,  83019213,  83166711,  83155031,  83237124,  83118501])
population_dict_NL_JRC   = np.array([ 15863950,  15987075,  16105285,  16192572,  16258032,  16305526,  16334210,  16357992,  16405399,  16485787,  16574989,  16655799,  16730348,  16779575,  16829289,  16900726,  16979120,  17081507,  17181084,  17282163,  17407585,  17475415,  17590672,  17811291])

tertiary_floor_area_tot_EU27_JRC = np.array([7887643, 8038659, 8168911, 8297145, 8455130, 8614843, 8850213, 9087228, 9241407, 9226687, 9323148, 9375270, 9444916, 9476214, 9558085, 9642879, 9745169, 9844065, 9937229, 10019388, 10092121, 10158425, 10220367, 10278644])*1e+3
tertiary_floor_area_tot_FR_JRC   = np.array([ 832817,  845160,  857503,  869847,  882190,  894534,  907925,  924435,  937827,  943944,  955210,  967802,  975122,  981236,  993332,  993004, 1001521, 1010801, 1021627,  1032263,  1042193,  1051737,  1061033,  1070222])*1e+3
tertiary_floor_area_tot_DE_JRC   = np.array([2940183, 2986106, 3008241, 3021034, 3059723, 3088797, 3165938, 3240084, 3278145, 3261752, 3290947, 3286530, 3307198, 3322342, 3344747, 3375555, 3418229, 3448053, 3472731,  3491891,  3507000,  3518747,  3528526,  3536639])*1e+3
tertiary_floor_area_tot_NL_JRC   = np.array([ 349889,  355302,  358320,  359627,  358142,  363569,  372836,  384549,  391374,  389821,  393819,  398937,  400159,  399132,  399236,  405136,  406902,  409600,  412152,   414577,   416939,   419297,   421598,   423836])*1e+3

tertiary_floor_area_spe_EU27_JRC = tertiary_floor_area_tot_EU27_JRC/population_dict_EU27_JRC
tertiary_floor_area_spe_FR_JRC   = tertiary_floor_area_tot_FR_JRC  /population_dict_FR_JRC
tertiary_floor_area_spe_DE_JRC   = tertiary_floor_area_tot_DE_JRC  /population_dict_DE_JRC
tertiary_floor_area_spe_NL_JRC   = tertiary_floor_area_tot_NL_JRC  /population_dict_NL_JRC

# ODYSSEE
# -> Population: Eurostat
years_ODY = np.array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

population_dict_EU27_ODY = np.array([428473.83, 429240.75, 429723.14, 431190.18, 432762.04, 434416.27, 435816.24, 437227.50, 438725.39, 440047.89, 440660.42, 439942.31, 440552.66, 441739.93, 442268.08, 442924.87, 444003.27, 444670.61, 445301.38, 446149.92, 447030.02, 445891.01, 445972.02, 447695.35, 449306.18])*1e+3
population_dict_FR_ODY   = np.array([ 60545.02,  60979.32,  61424.04,  61864.09,  62292.24,  62772.87,  63229.64,  63645.07,  64007.19,  64350.23,  64658.86,  64978.72,  65276.98,  65600.35,  66165.98,  66458.15,  66638.39,  66809.82,  67026.22,  67290.47,  67473.65,  67728.57,  68091.70,  68277.21,  68467.36])*1e+3
population_dict_DE_ODY   = np.array([ 82163.48,  82259.54,  82440.31,  82536.68,  82531.67,  82500.85,  82438.00,  82314.91,  82217.84,  82002.36,  81802.26,  80222.07,  80327.90,  80523.75,  80767.46,  81197.54,  82175.68,  82521.65,  82792.35,  83019.21,  83166.71,  83155.03,  83237.12,  83118.50,  83456.05])*1e+3
population_dict_NL_ODY   = np.array([ 15863.95,  15987.08,  16105.29,  16192.57,  16258.03,  16305.53,  16334.21,  16357.99,  16405.40,  16485.79,  16574.99,  16655.80,  16730.35,  16779.58,  16829.29,  16900.73,  16979.12,  17081.51,  17181.08,  17282.16,  17407.59,  17475.42,  17590.67,  17811.29,  17942.94])*1e+3

tertiary_floor_area_tot_EU27_ODY = np.array([5130.05, 5181.80, 5233.61, 5225.88, 5205.34, 5170.65, 5144.32, 5225.69, 5390.11, 5468.18, 5520.25, 5546.46, 5601.04, 5666.63, 5704.54, 5755.59, 5810.42, 5861.48, 5918.79, 5937.73, 5991.95, 6052.13, 6074.90, 6103.61, 6127.29])*1e+6
tertiary_floor_area_tot_FR_ODY   = np.array([ 771.77,  780.96,  790.44,  796.93,  803.31,  810.85,  821.50,  834.59,  846.29,  854.16,  863.57,  872.05,  879.34,  889.65,  898.61,  908.31,  916.41,  925.14,  934.01,  943.38,  947.10,  957.81,  966.19,  976.03,  986.38])*1e+6
tertiary_floor_area_tot_DE_ODY   = np.array([ np.nan, 1789.33, 1745.69, 1703.46, 1658.40, 1619.00, 1579.60, 1600.00, 1688.00, 1710.00, 1734.00, 1742.00, 1752.00, 1762.00, 1772.00, 1782.06, 1792.17, 1802.34, 1812.57, 1802.39, 1908.69, 1926.09, 2105.14, 2103.46, 2149.77])*1e+6
tertiary_floor_area_tot_NL_ODY   = np.array([ 345.19,  352.37,  359.00,  364.61,  369.21,  373.55,  378.69,  383.36,  390.10,  396.09,  401.80,  405.34,  408.19,  411.84,  413.21,  415.99,  418.79,  421.57,  424.36,  418.86,  417.55,  420.33,  420.83,  424.41,  429.25])*1e+6

tertiary_floor_area_spe_EU27_ODY = tertiary_floor_area_tot_EU27_ODY/population_dict_EU27_ODY
tertiary_floor_area_spe_FR_ODY   = tertiary_floor_area_tot_FR_ODY  /population_dict_FR_ODY
tertiary_floor_area_spe_DE_ODY   = tertiary_floor_area_tot_DE_ODY  /population_dict_DE_ODY
tertiary_floor_area_spe_NL_ODY   = tertiary_floor_area_tot_NL_ODY  /population_dict_NL_ODY

# PLOTS
fig = plt.figure()
plt.plot(years_JRC,tertiary_floor_area_spe_EU27_JRC, '-o',label='JRC-IDEES, EU27',color='tab:blue')
plt.plot(years_ODY,tertiary_floor_area_spe_EU27_ODY,'--o',label='ODYSSEE, EU27',  color='tab:blue')
plt.plot(years_JRC,tertiary_floor_area_spe_FR_JRC,   '-o',label='JRC-IDEES, FR',color='tab:green')
plt.plot(years_ODY,tertiary_floor_area_spe_FR_ODY,  '--o',label='ODYSSEE, FR',  color='tab:green')
plt.plot(years_JRC,tertiary_floor_area_spe_NL_JRC,   '-o',label='JRC-IDEES, NL',color='tab:orange')
plt.plot(years_ODY,tertiary_floor_area_spe_NL_ODY,  '--o',label='ODYSSEE, NL',  color='tab:orange')
plt.plot(years_JRC,tertiary_floor_area_spe_DE_JRC ,  '-o',label='JRC-IDEES, DE',color='tab:red')
plt.plot(years_ODY,tertiary_floor_area_spe_DE_ODY,  '--o',label='ODYSSEE, DE',  color='tab:red')
plt.xlabel('years')
plt.ylabel('specific total tertiary floor area [m²/capita]')
plt.legend()
fig.tight_layout()

# %% [markdown]
# <font size="3"><b>Usefull heating demand</b></font><a class="anchor" id="contents"></a> <br>

# %%
# JRC-IDEES-2023-BE
years                     = np.array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])
floor_area                = np.array([175124, 177206, 185647, 187730, 192396, 195797, 200079, 204911, 208018, 206723, 211004, 214360, 215999, 217199, 218691, 219423, 221270, 222928, 225023, 227073, 229076, 231024, 232938, 234827])*1e+6
space_heating             = np.array([2203.6, 2336.2, 2389.5, 2546.7, 3164.2, 3138.2, 2933.9, 2688.9, 3085.3, 2964.2, 3197.2, 2570.0, 2757.4, 2999.8, 2306.6, 2649.0, 2668.0, 2647.3, 2666.7, 2540.0, 2466.3, 2650.7, 2111.0, 1960.4])*ktoe_to_GWh*1e-3
cooling                   = np.array([13.1, 16.3, 20.8, 30.5, 27.7, 32.9, 47.5, 43.2, 48.0, 53.5, 62.1, 61.8, 64.5, 67.6, 66.4, 74.9, 73.3, 68.5, 77.2, 73.7, 78.7, 63.8, 72.7, 66.2])*ktoe_to_GWh*1e-3
hot_water                 = np.array([362.0, 365.2, 387.1, 398.0, 382.4, 381.3, 387.6, 391.3, 392.9, 394.8, 399.9, 407.4, 414.7, 420.5, 423.2, 422.0, 424.4, 424.1, 419.8, 394.7, 372.7, 390.6, 391.5, 393.9])*ktoe_to_GWh*1e-3
catering                  = np.array([255.5, 264.0, 282.2, 287.5, 277.9, 280.1, 286.5, 299.4, 307.3, 312.0, 318.6, 324.8, 337.2, 341.6, 355.9, 366.5, 372.3, 376.1, 379.4, 370.1, 354.2, 365.0, 370.5, 373.8])*ktoe_to_GWh*1e-3
specific_electricity_uses = np.array([680.2, 706.8, 746.7, 772.4, 809.8, 849.5, 894.9, 937.4, 970.4, 988.3, 1016.9, 1039.1, 1050.7, 1059.9, 1072.2, 1087.8, 1082.7, 1088.8, 1071.5, 1052.5, 1006.3, 994.5, 991.1, 983.3])*ktoe_to_GWh*1e-3

# PRINTS
print(f'Total space heating demand (2019): {round(space_heating[-1],3)} TWh')

# PLOTS
fig = plt.figure()
plt.plot(years,            space_heating/floor_area*1e+12,'-o',label=f'space heating ({round((space_heating[-1]/floor_area[-1]-space_heating[0]/floor_area[0])/(space_heating[0]/floor_area[0])*100,1)}%)',color='tab:red')
plt.plot(years,                  cooling/floor_area*1e+12,'-o',label=f'cooling ({round((cooling[-1]/floor_area[-1]-cooling[0]/floor_area[0])/(cooling[0]/floor_area[0])*100,1)}%)',      color='tab:blue')
plt.plot(years,                hot_water/floor_area*1e+12,'-o',label=f'hot water ({round((hot_water[-1]/floor_area[-1]-hot_water[0]/floor_area[0])/(hot_water[0]/floor_area[0])*100,1)}%)',    color='tab:orange')
plt.plot(years,                 catering/floor_area*1e+12,'-o',label=f'catering ({round((catering[-1]/floor_area[-1]-catering[0]/floor_area[0])/(catering[0]/floor_area[0])*100,1)}%)',     color='tab:olive')
plt.plot(years,specific_electricity_uses/floor_area*1e+12,'-o',label=f'electricity ({round((specific_electricity_uses[-1]/floor_area[-1]-specific_electricity_uses[0]/floor_area[0])/(specific_electricity_uses[0]/floor_area[0])*100,1)}%)',  color='tab:green')
plt.xlabel('years')
plt.ylabel('specific usefull energy demand [kWh/m²]')
plt.legend()
fig.tight_layout()
# Out:
# Total space heating demand (2019): 22.799 TWh

# %% [markdown]
# <font size="5"><b>Residential Sector</b></font><a class="anchor" id="contents"></a> <br>
#
# **Renovation rate**

# %%
total_households_useful_surface_area   = np.array([544.891, 548.176, 552.649, 557.126, 561.428, 566.674, 569.394, 574.000, 579.360, 586.730, 591.848, 601.737, 604.095, 606.246, 608.402, 612.615, 614.555, 616.283, 620.212, 625.236, 628.893, 635.112, 641.103, 647.387])*1e+6
new_ren_households_useful_surface_area = np.array([np.nan, 15.669, 16.933, 17.040, 16.967, 18.012, 15.607, 17.557, 18.417, 20.553, 18.471, 23.362, 16.060, 15.911, 15.969, 18.079, 15.907, 15.744, 17.988, 19.178, 17.933, 20.584, 20.505, 20.943])*1e+6
renovation_rate = new_ren_households_useful_surface_area/total_households_useful_surface_area*100 # [%]

cum_ren_share = np.zeros(len(total_households_useful_surface_area))
for i in range(len(cum_ren_share)): cum_ren_share[i] = np.nansum(new_ren_households_useful_surface_area[0:i])/total_households_useful_surface_area[i]

print(cum_ren_share)

# PLOTS
fig = plt.figure()
plt.plot(years,renovation_rate,'-o')
plt.xlabel('years')
plt.ylabel('renovation rate [%]')
plt.title(f'mean: {round(np.nanmean(renovation_rate),1)}%, standard deviation {round(np.nanstd(renovation_rate),1)}%')
fig.tight_layout()
# Out:
# [0.         0.         0.02835253 0.05851818 0.08842096 0.11754377
#  0.1486159  0.17461324 0.20330192 0.23213744 0.26485686 0.29120031
#  0.32873637 0.35406089 0.37895832 0.40241914 0.43056683 0.45517076
#  0.47767215 0.50260382 0.53017604 0.55322053 0.58015795 0.6062    ]

# %% [markdown]
# **Thermal energy services**

# %%
ref_RS_tes_sht = np.array([3845.7, 4090.7, 3873.3, 4134.0, 3708.0, 3665.1, 3478.2, 3198.5, 3796.5, 3622.9, 4190.2, 3360.8, 3688.5, 4158.5, 3199.8, 3719.1, 3821.5, 3851.8, 3899.5, 3664.0, 3847.4, 4404.7, 3863.5, 3934.1])*ktoe_to_GWh
ref_RS_tes_scl = np.array([2.1, 2.7, 3.4, 9.6, 4.6, 6.2, 15.1, 7.5, 9.2, 11.1, 16.4, 13.6, 14.8, 16.7, 14.6, 23.1, 21.9, 22.5, 23.0, 23.5, 36.4, 45.8, 55.4, 56.2])*ktoe_to_GWh
ref_RS_tes_dhw = np.array([467.1, 455.5, 455.4, 458.5, 508.2, 526.9, 548.6, 541.3, 555.8, 578.2, 568.0, 557.1, 590.1, 591.6, 615.5, 616.2, 633.2, 631.3, 638.2, 663.4, 570.6, 571.6, 456.8, 437.7])*ktoe_to_GWh
ref_RS_tes_cok = np.array([86.1, 87.0, 85.8, 93.0, 96.1, 100.1, 98.8, 98.3, 84.0, 90.1, 90.6, 85.5, 90.3, 90.9, 92.5, 97.4, 98.9, 98.3, 97.5, 96.4, 102.9, 102.0, 77.1, 76.9])*ktoe_to_GWh

m_RS_tes_sht,b_RS_tes_sht = np.polyfit(years, ref_RS_tes_sht*1e+6/total_households_useful_surface_area, 1)
m_RS_tes_scl,b_RS_tes_scl = np.polyfit(years, ref_RS_tes_scl*1e+6/total_households_useful_surface_area, 1)
m_RS_tes_dhw,b_RS_tes_dhw = np.polyfit(years, ref_RS_tes_dhw*1e+6/population_dic_STATBEL, 1)
#m_RS_tes_cok,b_RS_tes_cok = np.polyfit(years, ref_RS_tes_cok*1e+6/households_dic_STATBEL, 1)
m_RS_tes_cok,b_RS_tes_cok = np.polyfit(years, ref_RS_tes_cok*1e+6/population_dic_STATBEL, 1)

# PLOTS
fig = plt.figure()
#plt.plot(years,ref_RS_tes_sht*1e+6/total_households_useful_surface_area,'-o',c='tab:blue',  label='space heating')
#plt.plot(years,m_RS_tes_sht*years+b_RS_tes_sht,                         '--',c='tab:blue')
plt.plot(years,ref_RS_tes_scl*1e+6/total_households_useful_surface_area,'-o',c='tab:orange',label='space cooling')
plt.plot(years,m_RS_tes_scl*years+b_RS_tes_scl,                         '--',c='tab:orange')
plt.xlabel('years')
plt.ylabel('specific energy consumption [kWh/m²]')
plt.legend()
fig.tight_layout()

print(f'SHT: {round(m_RS_tes_sht,3)} kWh/m²/year')
print(f'SCL: {round(m_RS_tes_scl,3)} kWh/m²/year')
print(f'DHW: {round(m_RS_tes_dhw,3)} kWh/person/year')
#print(f'COK: {round(m_RS_tes_cok,3)} kWh/household/year')
print(f'COK: {round(m_RS_tes_cok,3)} kWh/person/year')

print(f'SHT: {round(ref_RS_tes_sht[19]*1e+6/total_households_useful_surface_area[19],3)} kWh/m² (2019)')
print(f'SCL: {round(ref_RS_tes_scl[19]*1e+6/total_households_useful_surface_area[19],3)} kWh/m² (2019)')
print(f'DHW: {round(ref_RS_tes_dhw[19]*1e+6/population_dic_STATBEL[19],3)} kWh/person (2019)')
#print(f'COK: {round(ref_RS_tes_cok[19]*1e+6/households_dic_STATBEL[19],3)} kWh/household (2019)')
print(f'COK: {round(ref_RS_tes_cok[19]*1e+6/population_dic_STATBEL[19],3)} kWh/person (2019)')
# Out:
# SHT: -0.458 kWh/m²/year
# SCL: 0.035 kWh/m²/year
# DHW: 1.164 kWh/person/year
# COK: -0.523 kWh/person/year
# SHT: 68.154 kWh/m² (2019)
# SCL: 0.437 kWh/m² (2019)
# DHW: 674.925 kWh/person (2019)
# COK: 98.075 kWh/person (2019)

# %%
# PLOTS
fig = plt.figure()
#plt.plot(years,ref_RS_tes_dhw*1e+6/population_dic_STATBEL,'-o',c='tab:green', label='domestic hot water')
#plt.plot(years,m_RS_tes_dhw*years+b_RS_tes_dhw,                         '--',c='tab:green')
plt.plot(years,ref_RS_tes_cok*1e+6/population_dic_STATBEL,'-o',c='tab:red',   label='cooking')
plt.plot(years,m_RS_tes_cok*years+b_RS_tes_cok,                         '--',c='tab:red')
plt.xlabel('years')
plt.ylabel('specific energy consumption [kWh/person]')
plt.legend()
fig.tight_layout()

# %% [markdown]
# **Specific eletectrical uses**

# %%
ref_RS_ees_frg = np.array([292.6, 289.7, 290.3, 290.4, 289.5, 286.1, 287.0, 279.2, 277.2, 276.2, 270.0, 266.1, 259.5, 252.8, 245.5, 238.1, 229.7, 221.2, 213.2, 209.814, 204.9, 200.4, 196.0, 192.7])*ktoe_to_GWh
ref_RS_ees_wsh = np.array([95.9, 95.8, 97.1, 96.7, 95.2, 94.7, 94.5, 92.4, 89.1, 88.1, 85.5, 84.1, 81.5, 79.0, 75.8, 73.0, 70.1, 67.5, 65.8, 64.045, 62.6, 61.5, 60.4, 59.7])*ktoe_to_GWh
ref_RS_ees_dry = np.array([83.4, 83.6, 87.9, 90.9, 87.9, 92.3, 90.5, 93.4, 90.6, 93.4, 91.7, 90.2, 88.1, 87.6, 85.0, 82.6, 82.8, 78.8, 77.6, 73.446, 71.4, 67.1, 63.1, 59.4])*ktoe_to_GWh
ref_RS_ees_dsh = np.array([47.5, 49.1, 51.0, 52.0, 53.3, 55.1, 54.4, 57.2, 57.4, 58.2, 58.4, 58.7, 58.3, 59.1, 59.7, 59.0, 58.0, 57.5, 58.0, 59.199, 62.4, 67.1, 63.9, 63.0])*ktoe_to_GWh
ref_RS_ees_tvm = np.array([106.8, 123.3, 141.9, 158.6, 170.2, 190.1, 201.1, 214.0, 222.7, 232.7, 238.8, 247.2, 251.9, 254.0, 258.7, 269.1, 269.3, 264.1, 264.2, 257.507, 281.2, 282.4, 263.1, 252.1])*ktoe_to_GWh
ref_RS_ees_ict = np.array([23.1, 27.0, 30.8, 35.0, 38.8, 43.7, 46.5, 49.8, 53.6, 57.8, 60.4, 61.9, 63.5, 64.8, 68.8, 74.4, 79.3, 84.7, 92.1, 96.860, 113.8, 121.6, 119.1, 118.8])*ktoe_to_GWh
ref_RS_ees_lgt = np.array([198.5, 201.7, 204.7, 207.4, 206.0, 210.9, 211.9, 212.7, 213.8, 215.0, 212.8, 207.1, 199.1, 193.9, 188.3, 177.7, 166.6, 157.9, 150.6, 139.889, 145.3, 143.3, 129.6, 120.0])*ktoe_to_GWh
ref_RS_ees_oth = np.array([73.6, 74.3, 75.1, 75.9, 75.6, 77.4, 78.2, 79.0, 79.6, 80.9, 81.3, 83.1, 83.9, 84.5, 85.0, 86.5, 88.8, 91.6, 95.8, 97.004, 109.2, 112.5, 106.5, 103.4])*ktoe_to_GWh

m_RS_ees_frg,b_RS_ees_frg = np.polyfit(years, ref_RS_ees_frg*1e+6/households_dic_STATBEL, 1)
m_RS_ees_wsh,b_RS_ees_wsh = np.polyfit(years, ref_RS_ees_wsh*1e+6/households_dic_STATBEL, 1)
m_RS_ees_dry,b_RS_ees_dry = np.polyfit(years, ref_RS_ees_dry*1e+6/households_dic_STATBEL, 1)
m_RS_ees_dsh,b_RS_ees_dsh = np.polyfit(years, ref_RS_ees_dsh*1e+6/households_dic_STATBEL, 1)
m_RS_ees_tvm,b_RS_ees_tvm = np.polyfit(years, ref_RS_ees_tvm*1e+6/households_dic_STATBEL, 1)
m_RS_ees_ict,b_RS_ees_ict = np.polyfit(years, ref_RS_ees_ict*1e+6/households_dic_STATBEL, 1)
m_RS_ees_lgt,b_RS_ees_lgt = np.polyfit(years, ref_RS_ees_lgt*1e+6/households_dic_STATBEL, 1)
m_RS_ees_oth,b_RS_ees_oth = np.polyfit(years, ref_RS_ees_oth*1e+6/households_dic_STATBEL, 1)

print(f'FRG: {round(m_RS_ees_frg,3)} kWh/household/year')
print(f'WSH: {round(m_RS_ees_wsh,3)} kWh/household/year')
print(f'DRY: {round(m_RS_ees_dry,3)} kWh/household/year')
print(f'DSH: {round(m_RS_ees_dsh,3)} kWh/household/year')
print(f'TVM: {round(m_RS_ees_tvm,3)} kWh/household/year')
print(f'ICT: {round(m_RS_ees_ict,3)} kWh/household/year')
print(f'LGT: {round(m_RS_ees_lgt,3)} kWh/household/year')
print(f'OTH: {round(m_RS_ees_oth,3)} kWh/household/year')

print(f'FRG: {round(ref_RS_ees_frg[19]*1e+6/households_dic_STATBEL[19],1)} kWh/household (2019)')
print(f'WSH: {round(ref_RS_ees_wsh[19]*1e+6/households_dic_STATBEL[19],1)} kWh/household (2019)')
print(f'DRY: {round(ref_RS_ees_dry[19]*1e+6/households_dic_STATBEL[19],1)} kWh/household (2019)')
print(f'DSH: {round(ref_RS_ees_dsh[19]*1e+6/households_dic_STATBEL[19],1)} kWh/household (2019)')
print(f'TVM: {round(ref_RS_ees_tvm[19]*1e+6/households_dic_STATBEL[19],1)} kWh/household (2019)')
print(f'ICT: {round(ref_RS_ees_ict[19]*1e+6/households_dic_STATBEL[19],1)} kWh/household (2019)')
print(f'LGT: {round(ref_RS_ees_lgt[19]*1e+6/households_dic_STATBEL[19],1)} kWh/household (2019)')
print(f'OTH: {round(ref_RS_ees_oth[19]*1e+6/households_dic_STATBEL[19],1)} kWh/household (2019)')

# PLOTS
fig = plt.figure()
#plt.plot(years,ref_RS_ees_frg*1e+6/households_dic_STATBEL,'-o',c='tab:blue',  label='refrigeration')
#plt.plot(years,m_RS_ees_frg*years+b_RS_ees_frg,           '--',c='tab:blue')
#plt.plot(years,ref_RS_ees_wsh*1e+6/households_dic_STATBEL,'-o',c='tab:orange',label='washing machine')
#plt.plot(years,m_RS_ees_wsh*years+b_RS_ees_wsh,           '--',c='tab:orange')
#plt.plot(years,ref_RS_ees_dry*1e+6/households_dic_STATBEL,'-o',c='tab:green', label='clothes dryer')
#plt.plot(years,m_RS_ees_dry*years+b_RS_ees_dry,           '--',c='tab:green')
plt.plot(years,ref_RS_ees_dsh*1e+6/households_dic_STATBEL,'-o',c='tab:red',   label='dishwasher')
plt.plot(years,m_RS_ees_dsh*years+b_RS_ees_dsh,           '--',c='tab:red')
plt.xlabel('years')
plt.ylabel('specific energy consumption [kWh/household]')
plt.legend()
fig.tight_layout()

# PLOTS
fig = plt.figure()
plt.plot(years,ref_RS_ees_tvm*1e+6/households_dic_STATBEL,'-o',c='tab:blue',  label='TV & multimedia')
plt.plot(years,m_RS_ees_tvm*years+b_RS_ees_tvm,           '--',c='tab:blue')
plt.plot(years,ref_RS_ees_ict*1e+6/households_dic_STATBEL,'-o',c='tab:orange',label='ICT')
plt.plot(years,m_RS_ees_ict*years+b_RS_ees_ict,           '--',c='tab:orange')
plt.plot(years,ref_RS_ees_lgt*1e+6/households_dic_STATBEL,'-o',c='tab:green', label='light')
plt.plot(years,m_RS_ees_lgt*years+b_RS_ees_lgt,           '--',c='tab:green')
plt.plot(years,ref_RS_ees_oth*1e+6/households_dic_STATBEL,'-o',c='tab:red',   label='others')
plt.plot(years,m_RS_ees_oth*years+b_RS_ees_oth,           '--',c='tab:red')
plt.xlabel('years')
plt.ylabel('specific energy consumption [kWh/household]')
plt.legend()
fig.tight_layout()
# Out:
# FRG: -16.967 kWh/household/year
# WSH: -6.277 kWh/household/year
# DRY: -4.17 kWh/household/year
# DSH: 0.351 kWh/household/year
# TVM: 12.279 kWh/household/year
# ICT: 9.037 kWh/household/year
# LGT: -12.853 kWh/household/year
# OTH: 2.078 kWh/household/year
# FRG: 493.1 kWh/household (2019)
# WSH: 150.5 kWh/household (2019)
# DRY: 172.6 kWh/household (2019)
# DSH: 139.1 kWh/household (2019)
# TVM: 605.2 kWh/household (2019)
# ICT: 227.6 kWh/household (2019)
# LGT: 328.8 kWh/household (2019)
# OTH: 228.0 kWh/household (2019)

# %% [markdown]
# <font size="5"><b>Tertiary Sector</b></font><a class="anchor" id="contents"></a> <br>
#
# <font size="3"><b>Renovation rate</b></font><a class="anchor" id="contents"></a> <br>

# %%
total_tertiary_useful_surface_area   = np.array([175124, 177206, 185647, 187730, 192396, 195797, 200079, 204911, 208018, 206723, 211004, 214360, 215999, 217199, 218691, 219423, 221270, 222928, 225023, 227073, 229076, 231024, 232938, 234827])*1e+3
new_ren_tertiary_useful_surface_area = np.array([np.nan, 2782, 9150, 2826, 5416, 4171, 5065, 5632, 3926, 832, 5109, 4200, 2496, 2064, 2360, 1607, 2984, 2804, 3250, 3216, 3180, 3135, 3111, 3096])*1e+3
renovation_rate = new_ren_tertiary_useful_surface_area/total_tertiary_useful_surface_area*100 # [%]

cum_ren_share = np.zeros(len(total_tertiary_useful_surface_area))
for i in range(len(cum_ren_share)): cum_ren_share[i] = np.nansum(new_ren_tertiary_useful_surface_area[0:i])/total_tertiary_useful_surface_area[i]

print(cum_ren_share)

# PLOTS
fig = plt.figure()
plt.plot(years,renovation_rate,'-o')
plt.xlabel('years')
plt.ylabel('renovation rate [%]')
plt.title(f'mean: {round(np.nanmean(renovation_rate),1)}%, standard deviation {round(np.nanstd(renovation_rate),1)}%')
fig.tight_layout()
# Out:
# [0.         0.         0.01498543 0.06355937 0.07670638 0.10303529
#  0.12167694 0.14352573 0.16845658 0.18850346 0.18862202 0.20950271
#  0.22735753 0.23759317 0.24541019 0.25534698 0.26047815 0.27192636
#  0.28185563 0.29362364 0.30509525 0.31628749 0.32714714 0.33776355]

# %%
ref_TS_tes_sht = np.array([1229.4, 1311.6, 1309.6, 1389.3, 1893.8, 1890.1, 1784.3, 1666.5, 1902.0, 1863.4, 2018.1, 1652.0, 1799.0, 1984.6, 1542.9, 1782.8, 1825.8, 1845.9, 1903.9, 1862.949, 1838.6, 2038.2, 1669.2, 1586.8])*ktoe_to_GWh
ref_TS_tes_scl = np.array([26.8, 36.1, 50.1, 77.1, 73.8, 91.8, 138.7, 132.0, 152.4, 174.2, 209.1, 215.8, 233.2, 253.1, 257.9, 301.4, 306.1, 296.1, 343.1, 336.272, 368.1, 305.3, 353.6, 325.9])*ktoe_to_GWh
ref_TS_tes_shw = np.array([215.3, 218.5, 235.7, 244.8, 235.5, 237.3, 244.0, 248.9, 253.0, 256.7, 263.3, 271.6, 280.7, 289.5, 293.8, 295.9, 302.6, 308.3, 311.7, 299.836, 288.8, 308.5, 316.6, 325.8])*ktoe_to_GWh
ref_TS_tes_cat = np.array([171.0, 178.3, 197.0, 204.4, 195.9, 204.2, 210.1, 221.2, 227.3, 231.5, 236.4, 242.1, 252.0, 255.5, 268.9, 276.9, 283.4, 287.3, 291.4, 284.204, 272.6, 286.3, 291.0, 298.4])*ktoe_to_GWh

m_TS_tes_sht,b_TS_tes_sht = np.polyfit(years, ref_TS_tes_sht*1e+6/total_tertiary_useful_surface_area, 1)
m_TS_tes_scl,b_TS_tes_scl = np.polyfit(years, ref_TS_tes_scl*1e+6/total_tertiary_useful_surface_area, 1)
m_TS_tes_shw,b_TS_tes_shw = np.polyfit(years, ref_TS_tes_shw*1e+6/population_dic_STATBEL, 1)
m_TS_tes_cat,b_TS_tes_cat = np.polyfit(years, ref_TS_tes_cat*1e+6/population_dic_STATBEL, 1)

# PLOTS
fig = plt.figure()
#plt.plot(years,ref_TS_tes_sht*1e+6/total_tertiary_useful_surface_area,'-o',c='tab:blue',  label='space heating')
#plt.plot(years,m_TS_tes_sht*years+b_TS_tes_sht,                       '--',c='tab:blue')
plt.plot(years,ref_TS_tes_scl*1e+6/total_tertiary_useful_surface_area,'-o',c='tab:orange',label='space cooling')
plt.plot(years,m_TS_tes_scl*years+b_TS_tes_scl,                       '--',c='tab:orange')
plt.xlabel('years')
plt.ylabel('specific energy consumption [kWh/m²]')
plt.legend()
fig.tight_layout()

print(f'SHT: {round(m_TS_tes_sht,3)} kWh/m²/year')
print(f'SCL: {round(m_TS_tes_scl,3)} kWh/m²/year')
print(f'SHW: {round(m_TS_tes_shw,3)} kWh/person/year')
print(f'CAT: {round(m_TS_tes_cat,3)} kWh/person/year')

print(f'SHT: {round(ref_TS_tes_sht[19]*1e+6/total_tertiary_useful_surface_area[19],3)} kWh/m² (2019)')
print(f'SCL: {round(ref_TS_tes_scl[19]*1e+6/total_tertiary_useful_surface_area[19],3)} kWh/m² (2019)')
print(f'SHW: {round(ref_TS_tes_shw[19]*1e+6/population_dic_STATBEL[19],3)} kWh/person (2019)')
print(f'CAT: {round(ref_TS_tes_cat[19]*1e+6/population_dic_STATBEL[19],3)} kWh/person (2019)')
# Out:
# SHT: -0.154 kWh/m²/year
# SCL: 0.743 kWh/m²/year
# SHW: 3.082 kWh/person/year
# CAT: 4.297 kWh/person/year
# SHT: 95.415 kWh/m² (2019)
# SCL: 17.223 kWh/m² (2019)
# SHW: 305.045 kWh/person (2019)
# CAT: 289.141 kWh/person (2019)

# %%
# PLOTS
fig = plt.figure()
plt.plot(years,ref_TS_tes_shw*1e+6/population_dic_STATBEL,'-o',c='tab:green', label='sanitary hot water')
plt.plot(years,m_TS_tes_shw*years+b_TS_tes_shw,                         '--',c='tab:green')
plt.plot(years,ref_TS_tes_cat*1e+6/population_dic_STATBEL,'-o',c='tab:red',   label='catering')
plt.plot(years,m_TS_tes_cat*years+b_TS_tes_cat,                         '--',c='tab:red')
plt.xlabel('years')
plt.ylabel('specific energy consumption [kWh/person]')
plt.legend()
fig.tight_layout()

# %%
m_TS_tes_sht,b_TS_tes_sht = np.polyfit(years[21:23], ref_TS_tes_sht[21:23]*1e+6/total_tertiary_useful_surface_area[21:23], 1)
print(f'2021: {round(ref_TS_tes_sht[21]*1e+6/total_tertiary_useful_surface_area[21],3)} kWh/m²')
print(f'2023: {round(ref_TS_tes_sht[23]*1e+6/total_tertiary_useful_surface_area[23],3)} kWh/m²')
print(f'SHT: {round(m_TS_tes_sht,3)} kWh/m²/year')
# Out:
# 2021: 102.605 kWh/m²
# 2023: 78.588 kWh/m²
# SHT: -19.266 kWh/m²/year

# %%
m_TS_tes_scl,b_TS_tes_scl = np.polyfit(years[19:23], ref_TS_tes_scl[19:23]*1e+6/total_tertiary_useful_surface_area[19:23], 1)
print(f'2019: {round(ref_TS_tes_scl[19]*1e+6/total_tertiary_useful_surface_area[19],3)} kWh/m²')
print(f'2023: {round(ref_TS_tes_scl[23]*1e+6/total_tertiary_useful_surface_area[23],3)} kWh/m²')
print(f'SCL: {round(m_TS_tes_scl,3)} kWh/m²/year')
# Out:
# 2019: 17.223 kWh/m²
# 2023: 16.14 kWh/m²
# SCL: -0.202 kWh/m²/year

# %%
ref_TS_ees_vnt = np.array([49.7, 51.3, 54.1, 55.3, 57.0, 58.4, 60.6, 62.7, 64.7, 64.9, 66.5, 67.9, 68.8, 69.8, 70.7, 71.6, 71.6, 71.5, 71.5, 71.632, 71.5, 71.7, 71.6, 71.5])*ktoe_to_GWh
ref_TS_ees_slt = np.array([72.5, 73.0, 74.2, 74.9, 75.9, 77.2, 78.2, 79.5, 81.1, 82.5, 83.2, 84.1, 84.4, 85.0, 85.0, 84.8, 83.8, 83.3, 80.7, 77.819, 74.7, 72.3, 70.0, 68.4])*ktoe_to_GWh
ref_TS_ees_blt = np.array([283.9, 287.9, 300.9, 303.3, 309.8, 312.8, 318.1, 325.1, 330.1, 328.9, 337.3, 342.0, 343.6, 341.8, 341.1, 341.7, 333.4, 333.6, 315.5, 297.768, 264.9, 251.7, 243.0, 232.0])*ktoe_to_GWh
ref_TS_ees_frg = np.array([104.3, 105.7, 107.7, 110.9, 117.2, 129.6, 146.2, 156.5, 162.9, 169.7, 173.9, 176.3, 178.0, 179.5, 181.2, 183.8, 181.8, 180.6, 180.2, 179.674, 179.4, 179.4, 179.2, 179.3])*ktoe_to_GWh
ref_TS_ees_msc = np.array([87.1, 92.7, 102.1, 109.2, 118.3, 127.8, 136.9, 145.7, 152.4, 154.4, 159.7, 163.5, 165.8, 167.5, 169.2, 169.0, 172.2, 176.1, 177.1, 176.613, 167.8, 168.2, 171.8, 173.5])*ktoe_to_GWh
ref_TS_ees_ict = np.array([82.9, 96.2, 107.7, 118.8, 131.6, 143.7, 154.9, 167.9, 179.2, 187.9, 196.2, 205.1, 210.2, 216.3, 225.0, 236.8, 239.7, 243.7, 246.5, 248.983, 248.0, 251.2, 255.6, 258.6])*ktoe_to_GWh

m_TS_ees_vnt,b_TS_ees_vnt = np.polyfit(years, ref_TS_ees_vnt*1e+6/population_dic_STATBEL, 1)
m_TS_ees_slt,b_TS_ees_slt = np.polyfit(years, ref_TS_ees_slt*1e+6/population_dic_STATBEL, 1)
m_TS_ees_blt,b_TS_ees_blt = np.polyfit(years, ref_TS_ees_blt*1e+6/population_dic_STATBEL, 1)
m_TS_ees_frg,b_TS_ees_frg = np.polyfit(years, ref_TS_ees_frg*1e+6/population_dic_STATBEL, 1)
m_TS_ees_msc,b_TS_ees_msc = np.polyfit(years, ref_TS_ees_msc*1e+6/population_dic_STATBEL, 1)
m_TS_ees_ict,b_TS_ees_ict = np.polyfit(years, ref_TS_ees_ict*1e+6/population_dic_STATBEL, 1)

print(f'VNT: {round(m_TS_ees_vnt,3)} kWh/person/year')
print(f'SLT: {round(m_TS_ees_slt,3)} kWh/person/year')
print(f'BLT: {round(m_TS_ees_blt,3)} kWh/person/year')
print(f'FRG: {round(m_TS_ees_frg,3)} kWh/person/year')
print(f'MSC: {round(m_TS_ees_msc,3)} kWh/person/year')
print(f'ICT: {round(m_TS_ees_ict,3)} kWh/person/year')

print(f'VNT: {round(ref_TS_ees_vnt[19]*1e+6/population_dic_STATBEL[19],1)} kWh/person (2019)')
print(f'SLT: {round(ref_TS_ees_slt[19]*1e+6/population_dic_STATBEL[19],1)} kWh/person (2019)')
print(f'BLT: {round(ref_TS_ees_blt[19]*1e+6/population_dic_STATBEL[19],1)} kWh/person (2019)')
print(f'FRG: {round(ref_TS_ees_frg[19]*1e+6/population_dic_STATBEL[19],1)} kWh/person (2019)')
print(f'MSC: {round(ref_TS_ees_msc[19]*1e+6/population_dic_STATBEL[19],1)} kWh/person (2019)')
print(f'ICT: {round(ref_TS_ees_ict[19]*1e+6/population_dic_STATBEL[19],1)} kWh/person (2019)')

# PLOTS
fig = plt.figure()
plt.plot(years,ref_TS_ees_vnt*1e+6/population_dic_STATBEL,'-o',c='tab:blue',  label='ventilation')
plt.plot(years,m_TS_ees_vnt*years+b_TS_ees_vnt,           '--',c='tab:blue')
plt.plot(years,ref_TS_ees_slt*1e+6/population_dic_STATBEL,'-o',c='tab:orange',label='street lighting')
plt.plot(years,m_TS_ees_slt*years+b_TS_ees_slt,           '--',c='tab:orange')
plt.plot(years,ref_TS_ees_blt*1e+6/population_dic_STATBEL,'-o',c='tab:green', label='buildng lighting')
plt.plot(years,m_TS_ees_blt*years+b_TS_ees_blt,           '--',c='tab:green')
plt.plot(years,ref_TS_ees_frg*1e+6/population_dic_STATBEL,'-o',c='tab:red',   label='commercial refrigeration')
plt.plot(years,m_TS_ees_frg*years+b_TS_ees_frg,           '--',c='tab:red')
plt.plot(years,ref_TS_ees_msc*1e+6/population_dic_STATBEL,'-o',c='tab:brown', label='miscellaneous')
plt.plot(years,m_TS_ees_msc*years+b_TS_ees_msc,           '--',c='tab:brown')
plt.plot(years,ref_TS_ees_ict*1e+6/population_dic_STATBEL,'-o',c='tab:pink',  label='ICT')
plt.plot(years,m_TS_ees_ict*years+b_TS_ees_ict,           '--',c='tab:pink')
plt.xlabel('years')
plt.ylabel('specific energy consumption [kWh/person]')
plt.legend()
fig.tight_layout()
# Out:
# VNT: 0.618 kWh/person/year
# SLT: -0.476 kWh/person/year
# BLT: -3.458 kWh/person/year
# FRG: 2.852 kWh/person/year
# MSC: 2.943 kWh/person/year
# ICT: 7.017 kWh/person/year
# VNT: 72.9 kWh/person (2019)
# SLT: 79.2 kWh/person (2019)
# BLT: 302.9 kWh/person (2019)
# FRG: 182.8 kWh/person (2019)
# MSC: 179.7 kWh/person (2019)
# ICT: 253.3 kWh/person (2019)
